# %%
import os
os.getcwd()
os.chdir('C:\\Users\\13125\\Desktop\\DS_Intermediate_Level\\DataScienceProgram\\Class1')

# %% [markdown]
# # Homework02

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
loans_income = pd.read_csv('loans_income.csv')
loans_income.head()
# Out:
#         x
# 0   67000
# 1   52000
# 2  100000
# 3   78762
# 4   37041

# %%
loans_income.shape
# Out:
# (50000, 1)

# %%
# Draw a sample with 1000 observations
lisample = loans_income.sample(n=1000, random_state=33)
lisample.shape
# Out:
# (1000, 1)

# %%
# Implemented bootstrap to take 10, 50 , 100, 1000 times resampling to repeatedly draw a income sample with 10 incomes
from sklearn.utils import resample

# %%
for i in range(50):
    boot = resample(lisample, n_samples=10, random_state=1)
    print(boot)
# Out:
#             x
# 20348   63970
# 43151   42900
# 29041   71000
# 30314   75000
# 45487   53000
# 14589  165000
# 23114   45000
# 12582   47000
# 35313   86000
# 49286  120000
#             x
# 20348   63970
# 43151   42900
# 29041   71000
# 30314   75000
# 45487   53000
# 14589  165000
# 23114   45000
# 12582   47000
# 35313   86000
# 49286  120000
#             x
# 20348   63970
# 43151   42900
# 29041   71000
# 30314   75000
# 45487   53000
# 14589  165000
# 23114   45000
# 12582   47000
# 35313   86000
# 49286  120000
#             x
# 20348   63970
# 43151   42900
# 29041   71000
# 30314   75000
# 45487   53000
# 14589  165000
# 23114   45000
# 12582   47000
# 35313   86000
# 49286  120000
#             x
# 20348   63970
# 43151   42900
# 29041   71000
# 30314   75000
# 45487   53000
# 14589  165000
# 23114   45000
# 12582   47000
# 35313   86000
# 49286  120000
#             x
# 20348   63970
# 43151   42900
# 29041   71000
# 30314   75000
# 45487   53000
# 14589  165000
# ...

# %%
for i in range(50):
    boot = resample(lisample, n_samples=10, random_state=1)
    print(boot)

# %%
for i in range(100):
    boot = resample(lisample, n_samples=10, random_state=1)
    print(boot)

# %%
for i in range(1000):
    boot = resample(lisample, n_samples=10, random_state=1)
    print(boot)

# %%
# Implemented bootstrap to take 10, 50 , 100, 1000 times resampling to repeatedly draw a income sample with 100 incomes
for i in range(10):
    boot = resample(lisample, n_samples=100, random_state=1)
    print(boot)

# %%
for i in range(50):
    boot = resample(lisample, n_samples=100, random_state=1)
    print(boot)

# %%
for i in range(100):
    boot = resample(lisample, n_samples=100, random_state=1)
    print(boot)

# %%
for i in range(1000):
    boot = resample(lisample, n_samples=100, random_state=1)
    print(boot)
